# %%
import pandas as pd 
import pathlib
import ntpath
from Commons.data_processing import *
from Commons.DataProcessors.pd_processor import PDProcessor

# %%
# get all pd data files
std_files = get_files(r".\N_Glycosylation_Results\StandardProteins", exts=['.xlsx'])

mt10_files = get_files(r".\N_Glycosylation_Results\BCaP_MT10", exts=['.xlsx'])

# %%
# read each data file and concatenate contents

# instantiate main object
read_data = None

dilutions = {"1": "1x", "05": "2x", "025": "4x", "0125": "8x", "00625": "16x"}

for file in std_files:
    # get filename from full path
    base_name, _ = ntpath.splitext(ntpath.basename(file))
    
    # extract dilution, temperature and run #
    div = base_name.split("-")[0]
    div = div.split("_")
    dil, temp, run = div[-3:]

    # get sample group name
    group = ntpath.dirname(file)
    group = group.split('\\')[-1]
    
    # use PDProcessor class to read data
    data = PDProcessor([file], sample_name="_".join(div[-3:]))

    # create special columns with our extracted info
    data.add_special_column("dilution", dilutions[dil])
    data.add_special_column("temperature", temp)
    data.add_special_column("run", run)
    data.add_special_column("sample", group)

    # concatenate data
    if read_data is None:
        read_data = data
    else:
        # joining handled by PDProcessor class
        read_data.join_processors(data)

# %%
for file in mt10_files:
    # get filename from full path
    base_name, _ = ntpath.splitext(ntpath.basename(file))
    
    # extract dilution, temperature and run #
    div = base_name.split("-")[0]
    div = div.split("_")
    temp, dil, run = div[-3:]

    # get sample group name
    group = ntpath.dirname(file)
    group = group.split('\\')[-1]
    
    print(dil, temp, run, group)
    # use PDProcessor class to read data
#     data = PDProcessor([file], sample_name="_".join(div[-3:]))

#     # create special columns with our extracted info
#     data.add_special_column("dilution", dil)
#     data.add_special_column("temperature", temp)
#     data.add_special_column("run", run)
#     data.add_special_column("sample", group)

#     # concatenate data
#     if read_data is None:
#         read_data = data
#     else:
#         # joining handled by PDProcessor class
#         read_data.join_processors(data)

# read_data.alias_engine("")
# Out:
# 16x 30C run1 BCaP_MT10
# 16x 30C run2 BCaP_MT10
# 16x 30C run3 BCaP_MT10
# 1x 30C run1 BCaP_MT10
# 1x 30C run2 BCaP_MT10
# 1x 30C run3 BCaP_MT10
# 2x 30C run1 BCaP_MT10
# 2x 30C run2 BCaP_MT10
# 2x 30C run3 BCaP_MT10
# 4x 30C run1 BCaP_MT10
# 4x 30C run2 BCaP_MT10
# 4x 30C run3 BCaP_MT10
# 8x 30C run1 BCaP_MT10
# 8x 30C run2 BCaP_MT10
# 8x 30C run3 BCaP_MT10
# 16x 45C run1 BCaP_MT10
# 16x 45C run2 BCaP_MT10
# 16x 45C run3 BCaP_MT10
# 1x 45C run1 BCaP_MT10
# 1x 45C run2 BCaP_MT10
# 1x 45C run3 BCaP_MT10
# 2x 45C run1 BCaP_MT10
# 2x 45C run2 BCaP_MT10
# 2x 45C run3 BCaP_MT10
# 4x 45C run1 BCaP_MT10
# 4x 45C run2 BCaP_MT10
# 4x 45C run3 BCaP_MT10
# 8x 45C run1 BCaP_MT10
# 8x 45C run2 BCaP_MT10
# 8x 45C run3 BCaP_MT10
# 16x 60C run1 BCaP_MT10
# 16x 60C run2 BCaP_MT10
# 16x 60C run3 BCaP_MT10
# 1x 60C run1 BCaP_MT10
# 1x 60C run2 BCaP_MT10
# 1x 60C run3 BCaP_MT10
# 2x 60C run1 BCaP_MT10
# 2x 60C run2 BCaP_MT10
# 2x 60C run3 BCaP_MT10
# 4x 60C run1 BCaP_MT10
# 4x 60C run2 BCaP_MT10
# 4x 60C run3 BCaP_MT10
# 8x 60C run1 BCaP_MT10
# 8x 60C run2 BCaP_MT10
# 8x 60C run3 BCaP_MT10

# %%
# extract peptide contents from PDProcessor object
peptides = read_data.peptides

# map the concentration values to floats
conc_map = {"1": 1.0, "05": 0.5, "025": 0.25, "0125": 0.125, "00625": 0.0625}
peptides.loc[:, 'new_concentration'] = peptides.concentration.map(conc_map)

# map concentration to dilution
vals = list(conc_map.values())
dilutions = [f'{int(1/x)}x' for x in vals]
dil_map = dict(zip(vals, dilutions))
peptides.loc[:, 'dilution'] = peptides.new_concentration.map(dil_map)

# %%
peptides
# Out:
#     accession                                        description checked  \
# 0      P61823  Ribonuclease pancreatic OS=Bos taurus OX=9913 ...    True
# 1      P61823  Ribonuclease pancreatic OS=Bos taurus OX=9913 ...    True
# 2      P61823  Ribonuclease pancreatic OS=Bos taurus OX=9913 ...    True
# 3      P61823  Ribonuclease pancreatic OS=Bos taurus OX=9913 ...    True
# 4      P61823  Ribonuclease pancreatic OS=Bos taurus OX=9913 ...    True
# ..        ...                                                ...     ...
# 379    Q9H2F5  Enhancer of polycomb homolog 1 OS=Homo sapiens...    True
# 380    Q9H2F5  Enhancer of polycomb homolog 1 OS=Homo sapiens...    True
# 381    P21980  Protein-glutamine gamma-glutamyltransferase 2 ...    True
# 382    P21980  Protein-glutamine gamma-glutamyltransferase 2 ...    True
# 383    P21980  Protein-glutamine gamma-glutamyltransferase 2 ...    True
#
#     confidence annotated_sequence           modifications  \
# 0         High       [R].NLTK.[D]  1xHexNAc(2)Hex(9) [N1]
# 1         High       [R].NLTK.[D]  1xHexNAc(2)Hex(6) [N1]
# 2         High       [R].NLTK.[D]  1xHexNAc(2)Hex(7) [N1]
# 3         High       [R].NLTK.[D]  1xHexNAc(2)Hex(3) [N1]
# 4         High       [R].NLTK.[D]  1xHexNAc(2)Hex(8) [N1]
# ..         ...                ...                     ...
# 379        Low   [ARK].SINR.[ATS]  1xHexNAc(2)Hex(8) [N3]
# 380        Low   [ARK].SINR.[ATS]  1xHexNAc(4)Hex(5) [N3]
# 381        Low   [ARK].SINR.[ATS]  1xHexNAc(2)Hex(9) [N3]
# 382        Low   [ARK].SINR.[ATS]  1xHexNAc(2)Hex(8) [N3]
# 383        Low   [ARK].SINR.[ATS]  1xHexNAc(4)Hex(5) [N3]
#
#     master_protein_accessions   rt_min       mz_da charge  ...  \
# 0                      P61823  14.8788   1170.4657      2  ...
# 1                      P61823  15.0038   927.38654      2  ...
# 2                      P61823   15.106  1008.41254      2  ...
# 3                      P61823  15.1325   684.30701      2  ...
# 4                      P61823  15.1461  1089.43848      2  ...
# ..                        ...      ...         ...    ...  ...
# 379                    Q9H2F5   6.2792  1096.43213      2  ...
# 380                    Q9H2F5    6.824   1056.4325      2  ...
# 381                    Q9H2F5   6.2354  1177.45825      2  ...
# 382                    Q9H2F5   6.2792  1096.43213      2  ...
# 383                    Q9H2F5    6.824   1056.4325      2  ...
#
#     sequence_in_protein positions_in_proteins sequence     data_source  \
# 0              R.NLTK.D               [60-63]     NLTK  00625_30C_Run1
# 1              R.NLTK.D               [60-63]     NLTK  00625_30C_Run1
# 2              R.NLTK.D               [60-63]     NLTK  00625_30C_Run1
# 3              R.NLTK.D               [60-63]     NLTK  00625_30C_Run1
# 4              R.NLTK.D               [60-63]     NLTK  00625_30C_Run1
# ..                  ...                   ...      ...             ...
# 379  A.SINR.A; R.SINR.T    [33-36]; [552-555]     SINR     60C_8x_run3
# 380  A.SINR.A; R.SINR.T    [33-36]; [552-555]     SINR     60C_8x_run3
# 381            K.SINR.S             [415-418]     SINR     60C_8x_run3
# 382            K.SINR.S             [415-418]     SINR     60C_8x_run3
# 383            K.SINR.S             [415-418]     SINR     60C_8x_run3
#
#     concentration temperature   run            sample new_concentration  \
# 0           00625         30C  Run1  StandardProteins            0.0625
# 1           00625         30C  Run1  StandardProteins            0.0625
# 2           00625         30C  Run1  StandardProteins            0.0625
# 3           00625         30C  Run1  StandardProteins            0.0625
# 4           00625         30C  Run1  StandardProteins            0.0625
# ..            ...         ...   ...               ...               ...
# 379           60C          8x  run3         BCaP_MT10               NaN
# 380           60C          8x  run3         BCaP_MT10               NaN
# 381           60C          8x  run3         BCaP_MT10               NaN
# 382           60C          8x  run3         BCaP_MT10               NaN
# 383           60C          8x  run3         BCaP_MT10               NaN
#
#     dilution
# 0        16x
# 1        16x
# 2        16x
# 3        16x
# 4        16x
# ..       ...
# 379      NaN
# 380      NaN
# 381      NaN
# 382      NaN
# 383      NaN
#
# [59620 rows x 45 columns]

# %%
# fix column names
peptides.drop('concentration', axis=1, inplace=True)

cols = [c for c in peptides.columns]
cols[-2] = 'concentration'
peptides.columns = cols

# %%
# define functions to match glycan composition to type
def categorize_glycan(glycan):

    glycan = glycan.replace(")", ",")
    glycan = glycan.replace("(", " ")
    glycan = glycan.split(",")[:-1]
    d = {k: int(v) for [k, v] in [i.split(" ") for i in glycan]}

    if "NeuAc" in d or "NeuGc" in d:
        return "Sialylated"
    elif "Fuc" in d:
        if d["HexNAc"] > 2:
            return "Fucosylated"
        elif d["HexNAc"] == 2:
            if "Hex" in d:
                if d["Hex"] > 4:
                    return "Complex"
            else:
                return "Paucimannose"
    elif d["HexNAc"] > 2:
        return "Complex"
    elif d["HexNAc"] <= 2:
        if "Hex" in d:
            if d["Hex"] <= 9 and d["Hex"] > 4:
                return "High Mannose"

        return "Paucimannose"

def determine_degree_sial(glycan):

    degree_map = {
        1: 'Monosialylated',
        2: 'Disialylated',
        3: 'Trisialylated',
        4: 'Tetrasialylated',
        5: 'Pentasialylated',
    }

    glycan = glycan.replace(')', ',')
    glycan = glycan.replace('(', ' ')
    glycan = glycan.split(',')[:-1]
    d = {k:int(v) for [k, v] in [i.split(' ') for i in glycan]}

    if not 'NeuAc' in d and 'NeuGc' not in d:
        return 0
    else:
        total = int(d.get('NeuAc', 0)) + int(d.get('NeuGc', 0))
        return degree_map[total]

# %%
# extract only rows containing glycans
peptides = peptides[~peptides.glycan_composition.isna()] 

# get high scoring peptides
peptides = peptides.loc[
    (peptides.byonic_score >= 300) &
    (peptides.delta_mod_score >= 10), :]

# add new column
peptides['glycan'] = peptides.glycan_composition

# map glycan type and sialylation info
peptides.loc[:, "glycan_type"] = peptides.glycan.map(categorize_glycan)
peptides.loc[:, "degree_sial"] = peptides.glycan.map(determine_degree_sial)


# map unique glycopeptide id
peptides.loc[:, "pep_mods"] = peptides.apply(
    lambda x: x["sequence"] + "_" + x["glycan"], axis=1
)

# sort according to concentration
peptides = peptides.sort_values('concentration', ascending=False)

# reset index
peptides = peptides.reset_index()
peptides = peptides.drop('index', axis=1)

peptides.head(3)
# Out:
#   accession                                        description checked  \
# 0    P61823  Ribonuclease pancreatic OS=Bos taurus OX=9913 ...    True
# 1    P61823  Ribonuclease pancreatic OS=Bos taurus OX=9913 ...    True
# 2    P61823  Ribonuclease pancreatic OS=Bos taurus OX=9913 ...    True
#
#   confidence annotated_sequence                   modifications  \
# 0       High       [R].NLTK.[D]  1xHexNAc(4)Hex(6)NeuAc(1) [N1]
# 1       High     [R].NLTKDR.[C]          1xHexNAc(2)Hex(7) [N1]
# 2       High     [R].NLTKDR.[C]          1xHexNAc(2)Hex(2) [N1]
#
#   master_protein_accessions   rt_min    mz_da charge  ... sequence  \
# 0                    P61823  29.2006  1276.51      2  ...     NLTK
# 1                    P61823    19.35  1143.98      2  ...   NLTKDR
# 2                    P61823  21.5785  738.845      2  ...   NLTKDR
#
#   data_source temperature   run concentration dilution  \
# 0  1_60C_Run3         60C  Run3           1.0       1x
# 1  1_30C_Run3         30C  Run3           1.0       1x
# 2  1_30C_Run3         30C  Run3           1.0       1x
#
#                     glycan   glycan_type     degree_sial  \
# 0  HexNAc(4)Hex(6)NeuAc(1)    Sialylated  Monosialylated
# 1          HexNAc(2)Hex(7)  High Mannose               0
# 2          HexNAc(2)Hex(2)  Paucimannose               0
#
#                        pep_mods
# 0  NLTK_HexNAc(4)Hex(6)NeuAc(1)
# 1        NLTKDR_HexNAc(2)Hex(7)
# 2        NLTKDR_HexNAc(2)Hex(2)
#
# [3 rows x 47 columns]

# %%
# further reduce the dataset to include only those glycopeptides found in 2/3 of runs

final_results = pd.DataFrame()

# for each temperature
for t, temperature in iterate_contents('temperature', peptides, get_item=True):
    # for each concentration
    for c, concentration in iterate_contents('concentration', temperature, get_item=True):
        # count occurrences of peptides
        counts = concentration.pep_mods.value_counts()

        # keep only the ones with occurence >= 2
        valid_number = counts[counts.values >= 2].keys()
        valid_ids = concentration[concentration.pep_mods.isin(valid_number)]
        
        # append final results
        final_results = pd.concat([final_results, valid_ids])

final_results.reset_index(inplace=True)
final_results = final_results.drop('index', axis=1)

print(f'Original dataframe has been reduced from {len(peptides)} rows to {len(final_results)} rows')
# Out:
# Original dataframe has been reduced from 2470 rows to 2259 rows

# %%
# create an output location
export_loc = pathlib.PurePath('.', 'Working_Datafiles')
pathlib.Path(export_loc).mkdir(parents=True, exist_ok=True)

# export final dataframe as working document
export_filename = pathlib.PurePath(export_loc, 'All_N_Glycopeptides.csv')
final_results.to_csv(str(export_filename), index=False)

# %%
peptides.loc[
    (peptides.concentration==1.0) &
    (peptides.glycan_type=='Sialylated') &
    (peptides.degree_sial=='Monosialylated') &
    (peptides.sequence=='QNGTLSK') &
    (peptides.glycan == 'HexNAc(5)Hex(6)NeuAc(1)'), :
]
# Out:
#     accession                                        description checked  \
# 30     Q3SZR3  Alpha-1-acid glycoprotein OS=Bos taurus OX=991...    True
# 124    Q3SZR3  Alpha-1-acid glycoprotein OS=Bos taurus OX=991...    True
# 174    Q3SZR3  Alpha-1-acid glycoprotein OS=Bos taurus OX=991...    True
# 234    Q3SZR3  Alpha-1-acid glycoprotein OS=Bos taurus OX=991...    True
# 533    Q3SZR3  Alpha-1-acid glycoprotein OS=Bos taurus OX=991...    True
#
#     confidence annotated_sequence                   modifications  \
# 30        High    [R].QNGTLSK.[V]  1xHexNAc(5)Hex(6)NeuAc(1) [N2]
# 124       High    [R].QNGTLSK.[V]  1xHexNAc(5)Hex(6)NeuAc(1) [N2]
# 174       High    [R].QNGTLSK.[V]  1xHexNAc(5)Hex(6)NeuAc(1) [N2]
# 234       High    [R].QNGTLSK.[V]  1xHexNAc(5)Hex(6)NeuAc(1) [N2]
# 533       High    [R].QNGTLSK.[V]  1xHexNAc(5)Hex(6)NeuAc(1) [N2]
#
#     master_protein_accessions   rt_min    mz_da charge  ... sequence  \
# 30                     Q3SZR3  26.5127  1513.61      2  ...  QNGTLSK
# 124                    Q3SZR3  26.2705  1513.61      2  ...  QNGTLSK
# 174                    Q3SZR3  24.5519  1513.61      2  ...  QNGTLSK
# 234                    Q3SZR3  24.9925  1513.61      2  ...  QNGTLSK
# 533                    Q3SZR3  26.1591  1513.61      2  ...  QNGTLSK
#
#     data_source temperature   run concentration dilution  \
# 30   1_45C_Run1         45C  Run1           1.0       1x
# 124  1_45C_Run2         45C  Run2           1.0       1x
# 174  1_30C_Run3         30C  Run3           1.0       1x
# 234  1_30C_Run1         30C  Run1           1.0       1x
# 533  1_45C_Run3         45C  Run3           1.0       1x
#
#                       glycan glycan_type     degree_sial  \
# 30   HexNAc(5)Hex(6)NeuAc(1)  Sialylated  Monosialylated
# 124  HexNAc(5)Hex(6)NeuAc(1)  Sialylated  Monosialylated
# 174  HexNAc(5)Hex(6)NeuAc(1)  Sialylated  Monosialylated
# 234  HexNAc(5)Hex(6)NeuAc(1)  Sialylated  Monosialylated
# 533  HexNAc(5)Hex(6)NeuAc(1)  Sialylated  Monosialylated
#
#                                    pep_mods
# 30   QNGTLSK_1xHexNAc(5)Hex(6)NeuAc(1) [N2]
# 124  QNGTLSK_1xHexNAc(5)Hex(6)NeuAc(1) [N2]
# 174  QNGTLSK_1xHexNAc(5)Hex(6)NeuAc(1) [N2]
# 234  QNGTLSK_1xHexNAc(5)Hex(6)NeuAc(1) [N2]
# 533  QNGTLSK_1xHexNAc(5)Hex(6)NeuAc(1) [N2]
#
# [5 rows x 47 columns]
